# %%
from itertools import permutations
from collections import deque
import heapq

def generate_single_translocation(perm, start_idx, end_idx, insert_pos):
    """
    Generate a single translocation: move interval [start_idx:end_idx] to insert_pos.
    Returns the resulting permutation.
    """
    # Extract the interval (keeping its internal order)
    interval = perm[start_idx:end_idx]
    # Get the remaining elements
    remaining = perm[:start_idx] + perm[end_idx:]
    # Insert interval at the specified position
    result = remaining[:insert_pos] + interval + remaining[insert_pos:]
    return result

def get_all_possible_translocations(perm):
    """
    Get all possible single translocations from a given permutation.
    Returns list of (result_permutation, move_info) tuples.
    """
    translocations = []
    n = len(perm)
    
    # Try all possible intervals
    for start_idx in range(n):
        for end_idx in range(start_idx + 1, n + 1):
            interval = perm[start_idx:end_idx]
            remaining = perm[:start_idx] + perm[end_idx:]
            
            # Try all possible insertion positions
            for insert_pos in range(len(remaining) + 1):
                result = remaining[:insert_pos] + interval + remaining[insert_pos:]
                
                # Only include if different from original
                if result != perm:
                    move_info = {
                        'interval': interval,
                        'from_pos': (start_idx, end_idx),
                        'to_pos': insert_pos,
                        'description': f"Move {interval} from positions [{start_idx}:{end_idx}] to position {insert_pos}"
                    }
                    translocations.append((result, move_info))
    
    return translocations

def find_all_paths_exact_length(start_perm, target_perm, exact_length):
    """
    Find ALL possible paths of exactly the specified length.
    Returns list of (path, moves) tuples.
    """
    all_paths = []
    
    # Use DFS to explore all paths
    def dfs(current_perm, current_path, current_moves, remaining_steps):
        if remaining_steps == 0:
            if current_perm == target_perm:
                all_paths.append((current_path.copy(), current_moves.copy()))
            return
        
        # Generate all possible moves from current position
        possible_moves = get_all_possible_translocations(current_perm)
        
        for next_perm, move_info in possible_moves:
            # Avoid revisiting the same permutation in the current path (cycle detection)
            if next_perm not in current_path:
                current_path.append(next_perm)
                current_moves.append(move_info)
                
                dfs(next_perm, current_path, current_moves, remaining_steps - 1)
                
                # Backtrack
                current_path.pop()
                current_moves.pop()
    
    # Start DFS
    dfs(start_perm, [start_perm], [], exact_length)
    
    return all_paths

def analyze_all_paths(start_perm, target_perm, exact_length):
    """
    Find and display all possible paths of exact length.
    """
    start_str = ''.join(map(str, start_perm))
    target_str = ''.join(map(str, target_perm))
    
    print(f"FINDING ALL PATHS: {start_str} → {target_str} in exactly {exact_length} steps")
    print("=" * 80)
    
    all_paths = find_all_paths_exact_length(start_perm, target_perm, exact_length)
    
    if not all_paths:
        print(f"No paths found of exactly {exact_length} steps!")
        return
    
    print(f"Found {len(all_paths)} different paths of exactly {exact_length} steps:")
    print()
    
    for path_num, (path, moves) in enumerate(all_paths, 1):
        print(f"PATH {path_num}:")
        print("-" * 40)
        
        for i, perm in enumerate(path):
            perm_str = ''.join(map(str, perm))
            if i == 0:
                print(f"Step {i}: {perm_str} (start)")
            else:
                print(f"Step {i}: {perm_str}")
                print(f"       ← {moves[i-1]['description']}")
        
        print()
    
    return all_paths

def find_shortest_path_length(start_perm, target_perm, max_depth=10):
    """
    Find the shortest path length using BFS.
    """
    if start_perm == target_perm:
        return 0
    
    queue = deque([(start_perm, 0)])
    visited = {start_perm}
    
    while queue:
        current_perm, depth = queue.popleft()
        
        if depth >= max_depth:
            continue
            
        moves = get_all_possible_translocations(current_perm)
        for next_perm, _ in moves:
            if next_perm == target_perm:
                return depth + 1
            
            if next_perm not in visited:
                visited.add(next_perm)
                queue.append((next_perm, depth + 1))
    
    return float('inf')

def comprehensive_analysis(start_perm, target_perm):
    """
    Comprehensive analysis: find shortest path, then show all paths of that length.
    """
    start_str = ''.join(map(str, start_perm))
    target_str = ''.join(map(str, target_perm))
    
    print(f"COMPREHENSIVE ANALYSIS: {start_str} → {target_str}")
    print("=" * 80)
    
    # First, find the shortest path length
    shortest_length = find_shortest_path_length(start_perm, target_perm)
    
    if shortest_length == float('inf'):
        print("No path found!")
        return
    
    print(f"Shortest path length: {shortest_length} steps")
    print()
    
    # Now find all paths of that length
    analyze_all_paths(start_perm, target_perm, shortest_length)
    
    # Also show paths of length shortest_length + 1 if requested
    if shortest_length < 5:  # Don't go too deep
        print(f"\nPaths of length {shortest_length + 1}:")
        print("=" * 80)
        longer_paths = find_all_paths_exact_length(start_perm, target_perm, shortest_length + 1)
        print(f"Found {len(longer_paths)} paths of length {shortest_length + 1}")

if __name__ == "__main__":
    # Main test case: 1234 → 4321
    start = (1, 2, 3, 4)
    target = (4, 3, 2, 1)
    
    print("SPECIFIC REQUEST: All possible ways to transform 1234 → 4321 in exactly 3 steps")
    print("=" * 80)
    
    # Find all 3-step paths
    all_3_step_paths = analyze_all_paths(start, target, 3)
    
    print(f"\nSUMMARY:")
    print(f"Total number of different 3-step paths: {len(all_3_step_paths) if all_3_step_paths else 0}")
    
    # Also check what the shortest path actually is
    print("\n" + "=" * 80)
    print("VERIFICATION: What is the actual shortest path length?")
    shortest = find_shortest_path_length(start, target)
    print(f"Shortest path length: {shortest}")
    
    if shortest != 3:
        print(f"\nNote: The shortest path is {shortest} steps, not 3.")
        print("Showing all optimal paths:")
        analyze_all_paths(start, target, shortest)
# Out:
# SPECIFIC REQUEST: All possible ways to transform 1234 → 4321 in exactly 3 steps
# ================================================================================
# FINDING ALL PATHS: 1234 → 4321 in exactly 3 steps
# ================================================================================
# Found 320 different paths of exactly 3 steps:
#
# PATH 1:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (1,) from positions [0:1] to position 1
# Step 2: 3214
#        ← Move (2, 1) from positions [0:2] to position 1
# Step 3: 4321
#        ← Move (3, 2, 1) from positions [0:3] to position 1
#
# PATH 2:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (1,) from positions [0:1] to position 1
# Step 2: 3214
#        ← Move (2, 1) from positions [0:2] to position 1
# Step 3: 4321
#        ← Move (4,) from positions [3:4] to position 0
#
# PATH 3:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (1,) from positions [0:1] to position 1
# Step 2: 3421
#        ← Move (2, 1) from positions [0:2] to position 2
# Step 3: 4321
#        ← Move (3,) from positions [0:1] to position 1
#
# PATH 4:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (1,) from positions [0:1] to position 1
# Step 2: 3421
#        ← Move (2, 1) from positions [0:2] to position 2
# Step 3: 4321
#        ← Move (4,) from positions [1:2] to position 0
#
# PATH 5:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (1,) from positions [0:1] to position 1
# Step 2: 4213
#        ← Move (2, 1, 3) from positions [0:3] to position 1
# Step 3: 4321
#        ← Move (2, 1) from positions [1:3] to position 2
#
# PATH 6:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (1,) from positions [0:1] to position 1
# Step 2: 4213
#        ← Move (2, 1, 3) from positions [0:3] to position 1
# Step 3: 4321
#        ← Move (3,) from positions [3:4] to position 1
#
# PATH 7:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (1,) from positions [0:1] to position 1
# Step 2: 3214
#        ← Move (3,) from positions [2:3] to position 0
# Step 3: 4321
#        ← Move (3, 2, 1) from positions [0:3] to position 1
#
# PATH 8:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (1,) from positions [0:1] to position 1
# Step 2: 3214
#        ← Move (3,) from positions [2:3] to position 0
# Step 3: 4321
#        ← Move (4,) from positions [3:4] to position 0
#
# PATH 9:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (1,) from positions [0:1] to position 1
# Step 2: 2143
#        ← Move (3,) from positions [2:3] to position 3
# Step 3: 4321
#        ← Move (2, 1) from positions [0:2] to position 2
#
# PATH 10:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (1,) from positions [0:1] to position 1
# Step 2: 2143
#        ← Move (3,) from positions [2:3] to position 3
# Step 3: 4321
#        ← Move (4, 3) from positions [2:4] to position 0
#
# PATH 11:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (1,) from positions [0:1] to position 1
# Step 2: 3421
#        ← Move (3, 4) from positions [2:4] to position 0
# Step 3: 4321
#        ← Move (3,) from positions [0:1] to position 1
#
# PATH 12:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (1,) from positions [0:1] to position 1
# Step 2: 3421
#        ← Move (3, 4) from positions [2:4] to position 0
# Step 3: 4321
#        ← Move (4,) from positions [1:2] to position 0
#
# PATH 13:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (1,) from positions [0:1] to position 1
# Step 2: 4213
#        ← Move (4,) from positions [3:4] to position 0
# Step 3: 4321
#        ← Move (2, 1) from positions [1:3] to position 2
#
# PATH 14:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (1,) from positions [0:1] to position 1
# Step 2: 4213
#        ← Move (4,) from positions [3:4] to position 0
# Step 3: 4321
#        ← Move (3,) from positions [3:4] to position 1
#
# PATH 15:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (1,) from positions [0:1] to position 1
# Step 2: 2143
#        ← Move (4,) from positions [3:4] to position 2
# Step 3: 4321
#        ← Move (2, 1) from positions [0:2] to position 2
#
# PATH 16:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (1,) from positions [0:1] to position 1
# Step 2: 2143
#        ← Move (4,) from positions [3:4] to position 2
# Step 3: 4321
#        ← Move (4, 3) from positions [2:4] to position 0
#
# PATH 17:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (1,) from positions [0:1] to position 2
# Step 2: 3214
#        ← Move (2,) from positions [0:1] to position 1
# Step 3: 4321
#        ← Move (3, 2, 1) from positions [0:3] to position 1
#
# PATH 18:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (1,) from positions [0:1] to position 2
# Step 2: 3214
#        ← Move (2,) from positions [0:1] to position 1
# Step 3: 4321
#        ← Move (4,) from positions [3:4] to position 0
#
# PATH 19:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (1,) from positions [0:1] to position 2
# Step 2: 4231
#        ← Move (2, 3, 1) from positions [0:3] to position 1
# Step 3: 4321
#        ← Move (2,) from positions [1:2] to position 2
#
# PATH 20:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (1,) from positions [0:1] to position 2
# Step 2: 4231
#        ← Move (2, 3, 1) from positions [0:3] to position 1
# Step 3: 4321
#        ← Move (3,) from positions [2:3] to position 1
#
# PATH 21:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (1,) from positions [0:1] to position 2
# Step 2: 3214
#        ← Move (3,) from positions [1:2] to position 0
# Step 3: 4321
#        ← Move (3, 2, 1) from positions [0:3] to position 1
#
# PATH 22:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (1,) from positions [0:1] to position 2
# Step 2: 3214
#        ← Move (3,) from positions [1:2] to position 0
# Step 3: 4321
#        ← Move (4,) from positions [3:4] to position 0
#
# PATH 23:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (1,) from positions [0:1] to position 2
# Step 2: 2143
#        ← Move (3,) from positions [1:2] to position 3
# Step 3: 4321
#        ← Move (2, 1) from positions [0:2] to position 2
#
# PATH 24:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (1,) from positions [0:1] to position 2
# Step 2: 2143
#        ← Move (3,) from positions [1:2] to position 3
# Step 3: 4321
#        ← Move (4, 3) from positions [2:4] to position 0
#
# PATH 25:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (1,) from positions [0:1] to position 2
# Step 2: 2431
#        ← Move (3, 1) from positions [1:3] to position 2
# Step 3: 4321
#        ← Move (2,) from positions [0:1] to position 2
#
# PATH 26:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (1,) from positions [0:1] to position 2
# Step 2: 2431
#        ← Move (3, 1) from positions [1:3] to position 2
# Step 3: 4321
#        ← Move (4, 3) from positions [1:3] to position 0
#
# PATH 27:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (1,) from positions [0:1] to position 2
# Step 2: 2143
#        ← Move (1, 4) from positions [2:4] to position 1
# Step 3: 4321
#        ← Move (2, 1) from positions [0:2] to position 2
#
# PATH 28:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (1,) from positions [0:1] to position 2
# Step 2: 2143
#        ← Move (1, 4) from positions [2:4] to position 1
# Step 3: 4321
#        ← Move (4, 3) from positions [2:4] to position 0
#
# PATH 29:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (1,) from positions [0:1] to position 2
# Step 2: 4231
#        ← Move (4,) from positions [3:4] to position 0
# Step 3: 4321
#        ← Move (2,) from positions [1:2] to position 2
#
# PATH 30:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (1,) from positions [0:1] to position 2
# Step 2: 4231
#        ← Move (4,) from positions [3:4] to position 0
# Step 3: 4321
#        ← Move (3,) from positions [2:3] to position 1
#
# PATH 31:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (1,) from positions [0:1] to position 2
# Step 2: 2431
#        ← Move (4,) from positions [3:4] to position 1
# Step 3: 4321
#        ← Move (2,) from positions [0:1] to position 2
#
# PATH 32:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (1,) from positions [0:1] to position 2
# Step 2: 2431
#        ← Move (4,) from positions [3:4] to position 1
# Step 3: 4321
#        ← Move (4, 3) from positions [1:3] to position 0
#
# PATH 33:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2341
#        ← Move (1,) from positions [0:1] to position 3
# Step 2: 3241
#        ← Move (2,) from positions [0:1] to position 1
# Step 3: 4321
#        ← Move (3, 2) from positions [0:2] to position 1
#
# PATH 34:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2341
#        ← Move (1,) from positions [0:1] to position 3
# Step 2: 3241
#        ← Move (2,) from positions [0:1] to position 1
# Step 3: 4321
#        ← Move (4,) from positions [2:3] to position 0
#
# PATH 35:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2341
#        ← Move (1,) from positions [0:1] to position 3
# Step 2: 3421
#        ← Move (2,) from positions [0:1] to position 2
# Step 3: 4321
#        ← Move (3,) from positions [0:1] to position 1
#
# PATH 36:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2341
#        ← Move (1,) from positions [0:1] to position 3
# Step 2: 3421
#        ← Move (2,) from positions [0:1] to position 2
# Step 3: 4321
#        ← Move (4,) from positions [1:2] to position 0
#
# PATH 37:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2341
#        ← Move (1,) from positions [0:1] to position 3
# Step 2: 4231
#        ← Move (2, 3) from positions [0:2] to position 1
# Step 3: 4321
#        ← Move (2,) from positions [1:2] to position 2
#
# PATH 38:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2341
#        ← Move (1,) from positions [0:1] to position 3
# Step 2: 4231
#        ← Move (2, 3) from positions [0:2] to position 1
# Step 3: 4321
#        ← Move (3,) from positions [2:3] to position 1
#
# PATH 39:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2341
#        ← Move (1,) from positions [0:1] to position 3
# Step 2: 3241
#        ← Move (3,) from positions [1:2] to position 0
# Step 3: 4321
#        ← Move (3, 2) from positions [0:2] to position 1
#
# PATH 40:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2341
#        ← Move (1,) from positions [0:1] to position 3
# Step 2: 3241
#        ← Move (3,) from positions [1:2] to position 0
# Step 3: 4321
#        ← Move (4,) from positions [2:3] to position 0
#
# PATH 41:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2341
#        ← Move (1,) from positions [0:1] to position 3
# Step 2: 2431
#        ← Move (3,) from positions [1:2] to position 2
# Step 3: 4321
#        ← Move (2,) from positions [0:1] to position 2
#
# PATH 42:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2341
#        ← Move (1,) from positions [0:1] to position 3
# Step 2: 2431
#        ← Move (3,) from positions [1:2] to position 2
# Step 3: 4321
#        ← Move (4, 3) from positions [1:3] to position 0
#
# PATH 43:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2341
#        ← Move (1,) from positions [0:1] to position 3
# Step 2: 3421
#        ← Move (3, 4) from positions [1:3] to position 0
# Step 3: 4321
#        ← Move (3,) from positions [0:1] to position 1
#
# PATH 44:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2341
#        ← Move (1,) from positions [0:1] to position 3
# Step 2: 3421
#        ← Move (3, 4) from positions [1:3] to position 0
# Step 3: 4321
#        ← Move (4,) from positions [1:2] to position 0
#
# PATH 45:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2341
#        ← Move (1,) from positions [0:1] to position 3
# Step 2: 4231
#        ← Move (4,) from positions [2:3] to position 0
# Step 3: 4321
#        ← Move (2,) from positions [1:2] to position 2
#
# PATH 46:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2341
#        ← Move (1,) from positions [0:1] to position 3
# Step 2: 4231
#        ← Move (4,) from positions [2:3] to position 0
# Step 3: 4321
#        ← Move (3,) from positions [2:3] to position 1
#
# PATH 47:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2341
#        ← Move (1,) from positions [0:1] to position 3
# Step 2: 2431
#        ← Move (4,) from positions [2:3] to position 1
# Step 3: 4321
#        ← Move (2,) from positions [0:1] to position 2
#
# PATH 48:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2341
#        ← Move (1,) from positions [0:1] to position 3
# Step 2: 2431
#        ← Move (4,) from positions [2:3] to position 1
# Step 3: 4321
#        ← Move (4, 3) from positions [1:3] to position 0
#
# PATH 49:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3124
#        ← Move (1, 2) from positions [0:2] to position 1
# Step 2: 2431
#        ← Move (3, 1) from positions [0:2] to position 2
# Step 3: 4321
#        ← Move (2,) from positions [0:1] to position 2
#
# PATH 50:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3124
#        ← Move (1, 2) from positions [0:2] to position 1
# Step 2: 2431
#        ← Move (3, 1) from positions [0:2] to position 2
# Step 3: 4321
#        ← Move (4, 3) from positions [1:3] to position 0
#
# PATH 51:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3124
#        ← Move (1, 2) from positions [0:2] to position 1
# Step 2: 4312
#        ← Move (3, 1, 2) from positions [0:3] to position 1
# Step 3: 4321
#        ← Move (1,) from positions [2:3] to position 3
#
# PATH 52:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3124
#        ← Move (1, 2) from positions [0:2] to position 1
# Step 2: 4312
#        ← Move (3, 1, 2) from positions [0:3] to position 1
# Step 3: 4321
#        ← Move (2,) from positions [3:4] to position 2
#
# PATH 53:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3124
#        ← Move (1, 2) from positions [0:2] to position 1
# Step 2: 3214
#        ← Move (1,) from positions [1:2] to position 2
# Step 3: 4321
#        ← Move (3, 2, 1) from positions [0:3] to position 1
#
# PATH 54:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3124
#        ← Move (1, 2) from positions [0:2] to position 1
# Step 2: 3214
#        ← Move (1,) from positions [1:2] to position 2
# Step 3: 4321
#        ← Move (4,) from positions [3:4] to position 0
#
# PATH 55:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3124
#        ← Move (1, 2) from positions [0:2] to position 1
# Step 2: 3241
#        ← Move (1,) from positions [1:2] to position 3
# Step 3: 4321
#        ← Move (3, 2) from positions [0:2] to position 1
#
# PATH 56:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3124
#        ← Move (1, 2) from positions [0:2] to position 1
# Step 2: 3241
#        ← Move (1,) from positions [1:2] to position 3
# Step 3: 4321
#        ← Move (4,) from positions [2:3] to position 0
#
# PATH 57:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3124
#        ← Move (1, 2) from positions [0:2] to position 1
# Step 2: 3214
#        ← Move (2,) from positions [2:3] to position 1
# Step 3: 4321
#        ← Move (3, 2, 1) from positions [0:3] to position 1
#
# PATH 58:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3124
#        ← Move (1, 2) from positions [0:2] to position 1
# Step 2: 3214
#        ← Move (2,) from positions [2:3] to position 1
# Step 3: 4321
#        ← Move (4,) from positions [3:4] to position 0
#
# PATH 59:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3124
#        ← Move (1, 2) from positions [0:2] to position 1
# Step 2: 2431
#        ← Move (2, 4) from positions [2:4] to position 0
# Step 3: 4321
#        ← Move (2,) from positions [0:1] to position 2
#
# PATH 60:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3124
#        ← Move (1, 2) from positions [0:2] to position 1
# Step 2: 2431
#        ← Move (2, 4) from positions [2:4] to position 0
# Step 3: 4321
#        ← Move (4, 3) from positions [1:3] to position 0
#
# PATH 61:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3124
#        ← Move (1, 2) from positions [0:2] to position 1
# Step 2: 3241
#        ← Move (2, 4) from positions [2:4] to position 1
# Step 3: 4321
#        ← Move (3, 2) from positions [0:2] to position 1
#
# PATH 62:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3124
#        ← Move (1, 2) from positions [0:2] to position 1
# Step 2: 3241
#        ← Move (2, 4) from positions [2:4] to position 1
# Step 3: 4321
#        ← Move (4,) from positions [2:3] to position 0
#
# PATH 63:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3124
#        ← Move (1, 2) from positions [0:2] to position 1
# Step 2: 4312
#        ← Move (4,) from positions [3:4] to position 0
# Step 3: 4321
#        ← Move (1,) from positions [2:3] to position 3
#
# PATH 64:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3124
#        ← Move (1, 2) from positions [0:2] to position 1
# Step 2: 4312
#        ← Move (4,) from positions [3:4] to position 0
# Step 3: 4321
#        ← Move (2,) from positions [3:4] to position 2
#
# PATH 65:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3412
#        ← Move (1, 2) from positions [0:2] to position 2
# Step 2: 4312
#        ← Move (3,) from positions [0:1] to position 1
# Step 3: 4321
#        ← Move (1,) from positions [2:3] to position 3
#
# PATH 66:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3412
#        ← Move (1, 2) from positions [0:2] to position 2
# Step 2: 4312
#        ← Move (3,) from positions [0:1] to position 1
# Step 3: 4321
#        ← Move (2,) from positions [3:4] to position 2
#
# PATH 67:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3412
#        ← Move (1, 2) from positions [0:2] to position 2
# Step 2: 4132
#        ← Move (3,) from positions [0:1] to position 2
# Step 3: 4321
#        ← Move (1,) from positions [1:2] to position 3
#
# PATH 68:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3412
#        ← Move (1, 2) from positions [0:2] to position 2
# Step 2: 4132
#        ← Move (3,) from positions [0:1] to position 2
# Step 3: 4321
#        ← Move (3, 2) from positions [2:4] to position 1
#
# PATH 69:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3412
#        ← Move (1, 2) from positions [0:2] to position 2
# Step 2: 4312
#        ← Move (4,) from positions [1:2] to position 0
# Step 3: 4321
#        ← Move (1,) from positions [2:3] to position 3
#
# PATH 70:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3412
#        ← Move (1, 2) from positions [0:2] to position 2
# Step 2: 4312
#        ← Move (4,) from positions [1:2] to position 0
# Step 3: 4321
#        ← Move (2,) from positions [3:4] to position 2
#
# PATH 71:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3412
#        ← Move (1, 2) from positions [0:2] to position 2
# Step 2: 4132
#        ← Move (4, 1) from positions [1:3] to position 0
# Step 3: 4321
#        ← Move (1,) from positions [1:2] to position 3
#
# PATH 72:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3412
#        ← Move (1, 2) from positions [0:2] to position 2
# Step 2: 4132
#        ← Move (4, 1) from positions [1:3] to position 0
# Step 3: 4321
#        ← Move (3, 2) from positions [2:4] to position 1
#
# PATH 73:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3412
#        ← Move (1, 2) from positions [0:2] to position 2
# Step 2: 3241
#        ← Move (4, 1) from positions [1:3] to position 2
# Step 3: 4321
#        ← Move (3, 2) from positions [0:2] to position 1
#
# PATH 74:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3412
#        ← Move (1, 2) from positions [0:2] to position 2
# Step 2: 3241
#        ← Move (4, 1) from positions [1:3] to position 2
# Step 3: 4321
#        ← Move (4,) from positions [2:3] to position 0
#
# PATH 75:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3412
#        ← Move (1, 2) from positions [0:2] to position 2
# Step 2: 3421
#        ← Move (1,) from positions [2:3] to position 3
# Step 3: 4321
#        ← Move (3,) from positions [0:1] to position 1
#
# PATH 76:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3412
#        ← Move (1, 2) from positions [0:2] to position 2
# Step 2: 3421
#        ← Move (1,) from positions [2:3] to position 3
# Step 3: 4321
#        ← Move (4,) from positions [1:2] to position 0
#
# PATH 77:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3412
#        ← Move (1, 2) from positions [0:2] to position 2
# Step 2: 3241
#        ← Move (2,) from positions [3:4] to position 1
# Step 3: 4321
#        ← Move (3, 2) from positions [0:2] to position 1
#
# PATH 78:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3412
#        ← Move (1, 2) from positions [0:2] to position 2
# Step 2: 3241
#        ← Move (2,) from positions [3:4] to position 1
# Step 3: 4321
#        ← Move (4,) from positions [2:3] to position 0
#
# PATH 79:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3412
#        ← Move (1, 2) from positions [0:2] to position 2
# Step 2: 3421
#        ← Move (2,) from positions [3:4] to position 2
# Step 3: 4321
#        ← Move (3,) from positions [0:1] to position 1
#
# PATH 80:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 3412
#        ← Move (1, 2) from positions [0:2] to position 2
# Step 2: 3421
#        ← Move (2,) from positions [3:4] to position 2
# Step 3: 4321
#        ← Move (4,) from positions [1:2] to position 0
#
# PATH 81:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (1, 2, 3) from positions [0:3] to position 1
# Step 2: 4213
#        ← Move (1,) from positions [1:2] to position 2
# Step 3: 4321
#        ← Move (2, 1) from positions [1:3] to position 2
#
# PATH 82:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (1, 2, 3) from positions [0:3] to position 1
# Step 2: 4213
#        ← Move (1,) from positions [1:2] to position 2
# Step 3: 4321
#        ← Move (3,) from positions [3:4] to position 1
#
# PATH 83:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (1, 2, 3) from positions [0:3] to position 1
# Step 2: 4231
#        ← Move (1,) from positions [1:2] to position 3
# Step 3: 4321
#        ← Move (2,) from positions [1:2] to position 2
#
# PATH 84:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (1, 2, 3) from positions [0:3] to position 1
# Step 2: 4231
#        ← Move (1,) from positions [1:2] to position 3
# Step 3: 4321
#        ← Move (3,) from positions [2:3] to position 1
#
# PATH 85:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (1, 2, 3) from positions [0:3] to position 1
# Step 2: 4312
#        ← Move (1, 2) from positions [1:3] to position 2
# Step 3: 4321
#        ← Move (1,) from positions [2:3] to position 3
#
# PATH 86:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (1, 2, 3) from positions [0:3] to position 1
# Step 2: 4312
#        ← Move (1, 2) from positions [1:3] to position 2
# Step 3: 4321
#        ← Move (2,) from positions [3:4] to position 2
#
# PATH 87:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (1, 2, 3) from positions [0:3] to position 1
# Step 2: 4213
#        ← Move (2,) from positions [2:3] to position 1
# Step 3: 4321
#        ← Move (2, 1) from positions [1:3] to position 2
#
# PATH 88:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (1, 2, 3) from positions [0:3] to position 1
# Step 2: 4213
#        ← Move (2,) from positions [2:3] to position 1
# Step 3: 4321
#        ← Move (3,) from positions [3:4] to position 1
#
# PATH 89:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (1, 2, 3) from positions [0:3] to position 1
# Step 2: 4132
#        ← Move (2,) from positions [2:3] to position 3
# Step 3: 4321
#        ← Move (1,) from positions [1:2] to position 3
#
# PATH 90:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (1, 2, 3) from positions [0:3] to position 1
# Step 2: 4132
#        ← Move (2,) from positions [2:3] to position 3
# Step 3: 4321
#        ← Move (3, 2) from positions [2:4] to position 1
#
# PATH 91:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (1, 2, 3) from positions [0:3] to position 1
# Step 2: 4231
#        ← Move (2, 3) from positions [2:4] to position 1
# Step 3: 4321
#        ← Move (2,) from positions [1:2] to position 2
#
# PATH 92:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (1, 2, 3) from positions [0:3] to position 1
# Step 2: 4231
#        ← Move (2, 3) from positions [2:4] to position 1
# Step 3: 4321
#        ← Move (3,) from positions [2:3] to position 1
#
# PATH 93:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (1, 2, 3) from positions [0:3] to position 1
# Step 2: 4312
#        ← Move (3,) from positions [3:4] to position 1
# Step 3: 4321
#        ← Move (1,) from positions [2:3] to position 3
#
# PATH 94:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (1, 2, 3) from positions [0:3] to position 1
# Step 2: 4312
#        ← Move (3,) from positions [3:4] to position 1
# Step 3: 4321
#        ← Move (2,) from positions [3:4] to position 2
#
# PATH 95:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (1, 2, 3) from positions [0:3] to position 1
# Step 2: 4132
#        ← Move (3,) from positions [3:4] to position 2
# Step 3: 4321
#        ← Move (1,) from positions [1:2] to position 3
#
# PATH 96:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (1, 2, 3) from positions [0:3] to position 1
# Step 2: 4132
#        ← Move (3,) from positions [3:4] to position 2
# Step 3: 4321
#        ← Move (3, 2) from positions [2:4] to position 1
#
# PATH 97:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (2,) from positions [1:2] to position 0
# Step 2: 3214
#        ← Move (2, 1) from positions [0:2] to position 1
# Step 3: 4321
#        ← Move (3, 2, 1) from positions [0:3] to position 1
#
# PATH 98:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (2,) from positions [1:2] to position 0
# Step 2: 3214
#        ← Move (2, 1) from positions [0:2] to position 1
# Step 3: 4321
#        ← Move (4,) from positions [3:4] to position 0
#
# PATH 99:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (2,) from positions [1:2] to position 0
# Step 2: 3421
#        ← Move (2, 1) from positions [0:2] to position 2
# Step 3: 4321
#        ← Move (3,) from positions [0:1] to position 1
#
# PATH 100:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (2,) from positions [1:2] to position 0
# Step 2: 3421
#        ← Move (2, 1) from positions [0:2] to position 2
# Step 3: 4321
#        ← Move (4,) from positions [1:2] to position 0
#
# PATH 101:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (2,) from positions [1:2] to position 0
# Step 2: 4213
#        ← Move (2, 1, 3) from positions [0:3] to position 1
# Step 3: 4321
#        ← Move (2, 1) from positions [1:3] to position 2
#
# PATH 102:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (2,) from positions [1:2] to position 0
# Step 2: 4213
#        ← Move (2, 1, 3) from positions [0:3] to position 1
# Step 3: 4321
#        ← Move (3,) from positions [3:4] to position 1
#
# PATH 103:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (2,) from positions [1:2] to position 0
# Step 2: 3214
#        ← Move (3,) from positions [2:3] to position 0
# Step 3: 4321
#        ← Move (3, 2, 1) from positions [0:3] to position 1
#
# PATH 104:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (2,) from positions [1:2] to position 0
# Step 2: 3214
#        ← Move (3,) from positions [2:3] to position 0
# Step 3: 4321
#        ← Move (4,) from positions [3:4] to position 0
#
# PATH 105:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (2,) from positions [1:2] to position 0
# Step 2: 2143
#        ← Move (3,) from positions [2:3] to position 3
# Step 3: 4321
#        ← Move (2, 1) from positions [0:2] to position 2
#
# PATH 106:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (2,) from positions [1:2] to position 0
# Step 2: 2143
#        ← Move (3,) from positions [2:3] to position 3
# Step 3: 4321
#        ← Move (4, 3) from positions [2:4] to position 0
#
# PATH 107:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (2,) from positions [1:2] to position 0
# Step 2: 3421
#        ← Move (3, 4) from positions [2:4] to position 0
# Step 3: 4321
#        ← Move (3,) from positions [0:1] to position 1
#
# PATH 108:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (2,) from positions [1:2] to position 0
# Step 2: 3421
#        ← Move (3, 4) from positions [2:4] to position 0
# Step 3: 4321
#        ← Move (4,) from positions [1:2] to position 0
#
# PATH 109:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (2,) from positions [1:2] to position 0
# Step 2: 4213
#        ← Move (4,) from positions [3:4] to position 0
# Step 3: 4321
#        ← Move (2, 1) from positions [1:3] to position 2
#
# PATH 110:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (2,) from positions [1:2] to position 0
# Step 2: 4213
#        ← Move (4,) from positions [3:4] to position 0
# Step 3: 4321
#        ← Move (3,) from positions [3:4] to position 1
#
# PATH 111:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (2,) from positions [1:2] to position 0
# Step 2: 2143
#        ← Move (4,) from positions [3:4] to position 2
# Step 3: 4321
#        ← Move (2, 1) from positions [0:2] to position 2
#
# PATH 112:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2134
#        ← Move (2,) from positions [1:2] to position 0
# Step 2: 2143
#        ← Move (4,) from positions [3:4] to position 2
# Step 3: 4321
#        ← Move (4, 3) from positions [2:4] to position 0
#
# PATH 113:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1324
#        ← Move (2,) from positions [1:2] to position 2
# Step 2: 3214
#        ← Move (1,) from positions [0:1] to position 2
# Step 3: 4321
#        ← Move (3, 2, 1) from positions [0:3] to position 1
#
# PATH 114:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1324
#        ← Move (2,) from positions [1:2] to position 2
# Step 2: 3214
#        ← Move (1,) from positions [0:1] to position 2
# Step 3: 4321
#        ← Move (4,) from positions [3:4] to position 0
#
# PATH 115:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1324
#        ← Move (2,) from positions [1:2] to position 2
# Step 2: 3241
#        ← Move (1,) from positions [0:1] to position 3
# Step 3: 4321
#        ← Move (3, 2) from positions [0:2] to position 1
#
# PATH 116:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1324
#        ← Move (2,) from positions [1:2] to position 2
# Step 2: 3241
#        ← Move (1,) from positions [0:1] to position 3
# Step 3: 4321
#        ← Move (4,) from positions [2:3] to position 0
#
# PATH 117:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1324
#        ← Move (2,) from positions [1:2] to position 2
# Step 2: 4132
#        ← Move (1, 3, 2) from positions [0:3] to position 1
# Step 3: 4321
#        ← Move (1,) from positions [1:2] to position 3
#
# PATH 118:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1324
#        ← Move (2,) from positions [1:2] to position 2
# Step 2: 4132
#        ← Move (1, 3, 2) from positions [0:3] to position 1
# Step 3: 4321
#        ← Move (3, 2) from positions [2:4] to position 1
#
# PATH 119:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1324
#        ← Move (2,) from positions [1:2] to position 2
# Step 2: 3214
#        ← Move (3, 2) from positions [1:3] to position 0
# Step 3: 4321
#        ← Move (3, 2, 1) from positions [0:3] to position 1
#
# PATH 120:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1324
#        ← Move (2,) from positions [1:2] to position 2
# Step 2: 3214
#        ← Move (3, 2) from positions [1:3] to position 0
# Step 3: 4321
#        ← Move (4,) from positions [3:4] to position 0
#
# PATH 121:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1324
#        ← Move (2,) from positions [1:2] to position 2
# Step 2: 1432
#        ← Move (3, 2) from positions [1:3] to position 2
# Step 3: 4321
#        ← Move (1,) from positions [0:1] to position 3
#
# PATH 122:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1324
#        ← Move (2,) from positions [1:2] to position 2
# Step 2: 1432
#        ← Move (3, 2) from positions [1:3] to position 2
# Step 3: 4321
#        ← Move (4, 3, 2) from positions [1:4] to position 0
#
# PATH 123:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1324
#        ← Move (2,) from positions [1:2] to position 2
# Step 2: 3241
#        ← Move (3, 2, 4) from positions [1:4] to position 0
# Step 3: 4321
#        ← Move (3, 2) from positions [0:2] to position 1
#
# PATH 124:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1324
#        ← Move (2,) from positions [1:2] to position 2
# Step 2: 3241
#        ← Move (3, 2, 4) from positions [1:4] to position 0
# Step 3: 4321
#        ← Move (4,) from positions [2:3] to position 0
#
# PATH 125:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1324
#        ← Move (2,) from positions [1:2] to position 2
# Step 2: 4132
#        ← Move (4,) from positions [3:4] to position 0
# Step 3: 4321
#        ← Move (1,) from positions [1:2] to position 3
#
# PATH 126:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1324
#        ← Move (2,) from positions [1:2] to position 2
# Step 2: 4132
#        ← Move (4,) from positions [3:4] to position 0
# Step 3: 4321
#        ← Move (3, 2) from positions [2:4] to position 1
#
# PATH 127:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1324
#        ← Move (2,) from positions [1:2] to position 2
# Step 2: 1432
#        ← Move (4,) from positions [3:4] to position 1
# Step 3: 4321
#        ← Move (1,) from positions [0:1] to position 3
#
# PATH 128:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1324
#        ← Move (2,) from positions [1:2] to position 2
# Step 2: 1432
#        ← Move (4,) from positions [3:4] to position 1
# Step 3: 4321
#        ← Move (4, 3, 2) from positions [1:4] to position 0
#
# PATH 129:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1342
#        ← Move (2,) from positions [1:2] to position 3
# Step 2: 3421
#        ← Move (1,) from positions [0:1] to position 3
# Step 3: 4321
#        ← Move (3,) from positions [0:1] to position 1
#
# PATH 130:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1342
#        ← Move (2,) from positions [1:2] to position 3
# Step 2: 3421
#        ← Move (1,) from positions [0:1] to position 3
# Step 3: 4321
#        ← Move (4,) from positions [1:2] to position 0
#
# PATH 131:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1342
#        ← Move (2,) from positions [1:2] to position 3
# Step 2: 4132
#        ← Move (1, 3) from positions [0:2] to position 1
# Step 3: 4321
#        ← Move (1,) from positions [1:2] to position 3
#
# PATH 132:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1342
#        ← Move (2,) from positions [1:2] to position 3
# Step 2: 4132
#        ← Move (1, 3) from positions [0:2] to position 1
# Step 3: 4321
#        ← Move (3, 2) from positions [2:4] to position 1
#
# PATH 133:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1342
#        ← Move (2,) from positions [1:2] to position 3
# Step 2: 4213
#        ← Move (1, 3) from positions [0:2] to position 2
# Step 3: 4321
#        ← Move (2, 1) from positions [1:3] to position 2
#
# PATH 134:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1342
#        ← Move (2,) from positions [1:2] to position 3
# Step 2: 4213
#        ← Move (1, 3) from positions [0:2] to position 2
# Step 3: 4321
#        ← Move (3,) from positions [3:4] to position 1
#
# PATH 135:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1342
#        ← Move (2,) from positions [1:2] to position 3
# Step 2: 1432
#        ← Move (3,) from positions [1:2] to position 2
# Step 3: 4321
#        ← Move (1,) from positions [0:1] to position 3
#
# PATH 136:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1342
#        ← Move (2,) from positions [1:2] to position 3
# Step 2: 1432
#        ← Move (3,) from positions [1:2] to position 2
# Step 3: 4321
#        ← Move (4, 3, 2) from positions [1:4] to position 0
#
# PATH 137:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1342
#        ← Move (2,) from positions [1:2] to position 3
# Step 2: 3421
#        ← Move (3, 4, 2) from positions [1:4] to position 0
# Step 3: 4321
#        ← Move (3,) from positions [0:1] to position 1
#
# PATH 138:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1342
#        ← Move (2,) from positions [1:2] to position 3
# Step 2: 3421
#        ← Move (3, 4, 2) from positions [1:4] to position 0
# Step 3: 4321
#        ← Move (4,) from positions [1:2] to position 0
#
# PATH 139:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1342
#        ← Move (2,) from positions [1:2] to position 3
# Step 2: 4132
#        ← Move (4,) from positions [2:3] to position 0
# Step 3: 4321
#        ← Move (1,) from positions [1:2] to position 3
#
# PATH 140:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1342
#        ← Move (2,) from positions [1:2] to position 3
# Step 2: 4132
#        ← Move (4,) from positions [2:3] to position 0
# Step 3: 4321
#        ← Move (3, 2) from positions [2:4] to position 1
#
# PATH 141:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1342
#        ← Move (2,) from positions [1:2] to position 3
# Step 2: 1432
#        ← Move (4,) from positions [2:3] to position 1
# Step 3: 4321
#        ← Move (1,) from positions [0:1] to position 3
#
# PATH 142:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1342
#        ← Move (2,) from positions [1:2] to position 3
# Step 2: 1432
#        ← Move (4,) from positions [2:3] to position 1
# Step 3: 4321
#        ← Move (4, 3, 2) from positions [1:4] to position 0
#
# PATH 143:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1342
#        ← Move (2,) from positions [1:2] to position 3
# Step 2: 4213
#        ← Move (4, 2) from positions [2:4] to position 0
# Step 3: 4321
#        ← Move (2, 1) from positions [1:3] to position 2
#
# PATH 144:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1342
#        ← Move (2,) from positions [1:2] to position 3
# Step 2: 4213
#        ← Move (4, 2) from positions [2:4] to position 0
# Step 3: 4321
#        ← Move (3,) from positions [3:4] to position 1
#
# PATH 145:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (2, 3) from positions [1:3] to position 0
# Step 2: 3214
#        ← Move (2,) from positions [0:1] to position 1
# Step 3: 4321
#        ← Move (3, 2, 1) from positions [0:3] to position 1
#
# PATH 146:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (2, 3) from positions [1:3] to position 0
# Step 2: 3214
#        ← Move (2,) from positions [0:1] to position 1
# Step 3: 4321
#        ← Move (4,) from positions [3:4] to position 0
#
# PATH 147:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (2, 3) from positions [1:3] to position 0
# Step 2: 4231
#        ← Move (2, 3, 1) from positions [0:3] to position 1
# Step 3: 4321
#        ← Move (2,) from positions [1:2] to position 2
#
# PATH 148:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (2, 3) from positions [1:3] to position 0
# Step 2: 4231
#        ← Move (2, 3, 1) from positions [0:3] to position 1
# Step 3: 4321
#        ← Move (3,) from positions [2:3] to position 1
#
# PATH 149:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (2, 3) from positions [1:3] to position 0
# Step 2: 3214
#        ← Move (3,) from positions [1:2] to position 0
# Step 3: 4321
#        ← Move (3, 2, 1) from positions [0:3] to position 1
#
# PATH 150:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (2, 3) from positions [1:3] to position 0
# Step 2: 3214
#        ← Move (3,) from positions [1:2] to position 0
# Step 3: 4321
#        ← Move (4,) from positions [3:4] to position 0
#
# PATH 151:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (2, 3) from positions [1:3] to position 0
# Step 2: 2143
#        ← Move (3,) from positions [1:2] to position 3
# Step 3: 4321
#        ← Move (2, 1) from positions [0:2] to position 2
#
# PATH 152:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (2, 3) from positions [1:3] to position 0
# Step 2: 2143
#        ← Move (3,) from positions [1:2] to position 3
# Step 3: 4321
#        ← Move (4, 3) from positions [2:4] to position 0
#
# PATH 153:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (2, 3) from positions [1:3] to position 0
# Step 2: 2431
#        ← Move (3, 1) from positions [1:3] to position 2
# Step 3: 4321
#        ← Move (2,) from positions [0:1] to position 2
#
# PATH 154:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (2, 3) from positions [1:3] to position 0
# Step 2: 2431
#        ← Move (3, 1) from positions [1:3] to position 2
# Step 3: 4321
#        ← Move (4, 3) from positions [1:3] to position 0
#
# PATH 155:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (2, 3) from positions [1:3] to position 0
# Step 2: 2143
#        ← Move (1, 4) from positions [2:4] to position 1
# Step 3: 4321
#        ← Move (2, 1) from positions [0:2] to position 2
#
# PATH 156:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (2, 3) from positions [1:3] to position 0
# Step 2: 2143
#        ← Move (1, 4) from positions [2:4] to position 1
# Step 3: 4321
#        ← Move (4, 3) from positions [2:4] to position 0
#
# PATH 157:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (2, 3) from positions [1:3] to position 0
# Step 2: 4231
#        ← Move (4,) from positions [3:4] to position 0
# Step 3: 4321
#        ← Move (2,) from positions [1:2] to position 2
#
# PATH 158:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (2, 3) from positions [1:3] to position 0
# Step 2: 4231
#        ← Move (4,) from positions [3:4] to position 0
# Step 3: 4321
#        ← Move (3,) from positions [2:3] to position 1
#
# PATH 159:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (2, 3) from positions [1:3] to position 0
# Step 2: 2431
#        ← Move (4,) from positions [3:4] to position 1
# Step 3: 4321
#        ← Move (2,) from positions [0:1] to position 2
#
# PATH 160:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 2314
#        ← Move (2, 3) from positions [1:3] to position 0
# Step 2: 2431
#        ← Move (4,) from positions [3:4] to position 1
# Step 3: 4321
#        ← Move (4, 3) from positions [1:3] to position 0
#
# PATH 161:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (2, 3) from positions [1:3] to position 2
# Step 2: 4213
#        ← Move (1,) from positions [0:1] to position 2
# Step 3: 4321
#        ← Move (2, 1) from positions [1:3] to position 2
#
# PATH 162:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (2, 3) from positions [1:3] to position 2
# Step 2: 4213
#        ← Move (1,) from positions [0:1] to position 2
# Step 3: 4321
#        ← Move (3,) from positions [3:4] to position 1
#
# PATH 163:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (2, 3) from positions [1:3] to position 2
# Step 2: 4231
#        ← Move (1,) from positions [0:1] to position 3
# Step 3: 4321
#        ← Move (2,) from positions [1:2] to position 2
#
# PATH 164:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (2, 3) from positions [1:3] to position 2
# Step 2: 4231
#        ← Move (1,) from positions [0:1] to position 3
# Step 3: 4321
#        ← Move (3,) from positions [2:3] to position 1
#
# PATH 165:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (2, 3) from positions [1:3] to position 2
# Step 2: 2143
#        ← Move (1, 4) from positions [0:2] to position 1
# Step 3: 4321
#        ← Move (2, 1) from positions [0:2] to position 2
#
# PATH 166:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (2, 3) from positions [1:3] to position 2
# Step 2: 2143
#        ← Move (1, 4) from positions [0:2] to position 1
# Step 3: 4321
#        ← Move (4, 3) from positions [2:4] to position 0
#
# PATH 167:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (2, 3) from positions [1:3] to position 2
# Step 2: 4213
#        ← Move (4, 2) from positions [1:3] to position 0
# Step 3: 4321
#        ← Move (2, 1) from positions [1:3] to position 2
#
# PATH 168:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (2, 3) from positions [1:3] to position 2
# Step 2: 4213
#        ← Move (4, 2) from positions [1:3] to position 0
# Step 3: 4321
#        ← Move (3,) from positions [3:4] to position 1
#
# PATH 169:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (2, 3) from positions [1:3] to position 2
# Step 2: 4231
#        ← Move (4, 2, 3) from positions [1:4] to position 0
# Step 3: 4321
#        ← Move (2,) from positions [1:2] to position 2
#
# PATH 170:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (2, 3) from positions [1:3] to position 2
# Step 2: 4231
#        ← Move (4, 2, 3) from positions [1:4] to position 0
# Step 3: 4321
#        ← Move (3,) from positions [2:3] to position 1
#
# PATH 171:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (2, 3) from positions [1:3] to position 2
# Step 2: 2143
#        ← Move (2,) from positions [2:3] to position 0
# Step 3: 4321
#        ← Move (2, 1) from positions [0:2] to position 2
#
# PATH 172:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (2, 3) from positions [1:3] to position 2
# Step 2: 2143
#        ← Move (2,) from positions [2:3] to position 0
# Step 3: 4321
#        ← Move (4, 3) from positions [2:4] to position 0
#
# PATH 173:
# ----------------------------------------
# ...
#
# PATH 264:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1342
#        ← Move (3, 4) from positions [2:4] to position 1
# Step 2: 1432
#        ← Move (3,) from positions [1:2] to position 2
# Step 3: 4321
#        ← Move (4, 3, 2) from positions [1:4] to position 0
#
# PATH 265:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1342
#        ← Move (3, 4) from positions [2:4] to position 1
# Step 2: 3421
#        ← Move (3, 4, 2) from positions [1:4] to position 0
# Step 3: 4321
#        ← Move (3,) from positions [0:1] to position 1
#
# PATH 266:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1342
#        ← Move (3, 4) from positions [2:4] to position 1
# Step 2: 3421
#        ← Move (3, 4, 2) from positions [1:4] to position 0
# Step 3: 4321
#        ← Move (4,) from positions [1:2] to position 0
#
# PATH 267:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1342
#        ← Move (3, 4) from positions [2:4] to position 1
# Step 2: 4132
#        ← Move (4,) from positions [2:3] to position 0
# Step 3: 4321
#        ← Move (1,) from positions [1:2] to position 3
#
# PATH 268:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1342
#        ← Move (3, 4) from positions [2:4] to position 1
# Step 2: 4132
#        ← Move (4,) from positions [2:3] to position 0
# Step 3: 4321
#        ← Move (3, 2) from positions [2:4] to position 1
#
# PATH 269:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1342
#        ← Move (3, 4) from positions [2:4] to position 1
# Step 2: 1432
#        ← Move (4,) from positions [2:3] to position 1
# Step 3: 4321
#        ← Move (1,) from positions [0:1] to position 3
#
# PATH 270:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1342
#        ← Move (3, 4) from positions [2:4] to position 1
# Step 2: 1432
#        ← Move (4,) from positions [2:3] to position 1
# Step 3: 4321
#        ← Move (4, 3, 2) from positions [1:4] to position 0
#
# PATH 271:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1342
#        ← Move (3, 4) from positions [2:4] to position 1
# Step 2: 4213
#        ← Move (4, 2) from positions [2:4] to position 0
# Step 3: 4321
#        ← Move (2, 1) from positions [1:3] to position 2
#
# PATH 272:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1342
#        ← Move (3, 4) from positions [2:4] to position 1
# Step 2: 4213
#        ← Move (4, 2) from positions [2:4] to position 0
# Step 3: 4321
#        ← Move (3,) from positions [3:4] to position 1
#
# PATH 273:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (4,) from positions [3:4] to position 0
# Step 2: 4213
#        ← Move (1,) from positions [1:2] to position 2
# Step 3: 4321
#        ← Move (2, 1) from positions [1:3] to position 2
#
# PATH 274:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (4,) from positions [3:4] to position 0
# Step 2: 4213
#        ← Move (1,) from positions [1:2] to position 2
# Step 3: 4321
#        ← Move (3,) from positions [3:4] to position 1
#
# PATH 275:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (4,) from positions [3:4] to position 0
# Step 2: 4231
#        ← Move (1,) from positions [1:2] to position 3
# Step 3: 4321
#        ← Move (2,) from positions [1:2] to position 2
#
# PATH 276:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (4,) from positions [3:4] to position 0
# Step 2: 4231
#        ← Move (1,) from positions [1:2] to position 3
# Step 3: 4321
#        ← Move (3,) from positions [2:3] to position 1
#
# PATH 277:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (4,) from positions [3:4] to position 0
# Step 2: 4312
#        ← Move (1, 2) from positions [1:3] to position 2
# Step 3: 4321
#        ← Move (1,) from positions [2:3] to position 3
#
# PATH 278:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (4,) from positions [3:4] to position 0
# Step 2: 4312
#        ← Move (1, 2) from positions [1:3] to position 2
# Step 3: 4321
#        ← Move (2,) from positions [3:4] to position 2
#
# PATH 279:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (4,) from positions [3:4] to position 0
# Step 2: 4213
#        ← Move (2,) from positions [2:3] to position 1
# Step 3: 4321
#        ← Move (2, 1) from positions [1:3] to position 2
#
# PATH 280:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (4,) from positions [3:4] to position 0
# Step 2: 4213
#        ← Move (2,) from positions [2:3] to position 1
# Step 3: 4321
#        ← Move (3,) from positions [3:4] to position 1
#
# PATH 281:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (4,) from positions [3:4] to position 0
# Step 2: 4132
#        ← Move (2,) from positions [2:3] to position 3
# Step 3: 4321
#        ← Move (1,) from positions [1:2] to position 3
#
# PATH 282:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (4,) from positions [3:4] to position 0
# Step 2: 4132
#        ← Move (2,) from positions [2:3] to position 3
# Step 3: 4321
#        ← Move (3, 2) from positions [2:4] to position 1
#
# PATH 283:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (4,) from positions [3:4] to position 0
# Step 2: 4231
#        ← Move (2, 3) from positions [2:4] to position 1
# Step 3: 4321
#        ← Move (2,) from positions [1:2] to position 2
#
# PATH 284:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (4,) from positions [3:4] to position 0
# Step 2: 4231
#        ← Move (2, 3) from positions [2:4] to position 1
# Step 3: 4321
#        ← Move (3,) from positions [2:3] to position 1
#
# PATH 285:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (4,) from positions [3:4] to position 0
# Step 2: 4312
#        ← Move (3,) from positions [3:4] to position 1
# Step 3: 4321
#        ← Move (1,) from positions [2:3] to position 3
#
# PATH 286:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (4,) from positions [3:4] to position 0
# Step 2: 4312
#        ← Move (3,) from positions [3:4] to position 1
# Step 3: 4321
#        ← Move (2,) from positions [3:4] to position 2
#
# PATH 287:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (4,) from positions [3:4] to position 0
# Step 2: 4132
#        ← Move (3,) from positions [3:4] to position 2
# Step 3: 4321
#        ← Move (1,) from positions [1:2] to position 3
#
# PATH 288:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 4123
#        ← Move (4,) from positions [3:4] to position 0
# Step 2: 4132
#        ← Move (3,) from positions [3:4] to position 2
# Step 3: 4321
#        ← Move (3, 2) from positions [2:4] to position 1
#
# PATH 289:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (4,) from positions [3:4] to position 1
# Step 2: 4213
#        ← Move (1,) from positions [0:1] to position 2
# Step 3: 4321
#        ← Move (2, 1) from positions [1:3] to position 2
#
# PATH 290:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (4,) from positions [3:4] to position 1
# Step 2: 4213
#        ← Move (1,) from positions [0:1] to position 2
# Step 3: 4321
#        ← Move (3,) from positions [3:4] to position 1
#
# PATH 291:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (4,) from positions [3:4] to position 1
# Step 2: 4231
#        ← Move (1,) from positions [0:1] to position 3
# Step 3: 4321
#        ← Move (2,) from positions [1:2] to position 2
#
# PATH 292:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (4,) from positions [3:4] to position 1
# Step 2: 4231
#        ← Move (1,) from positions [0:1] to position 3
# Step 3: 4321
#        ← Move (3,) from positions [2:3] to position 1
#
# PATH 293:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (4,) from positions [3:4] to position 1
# Step 2: 2143
#        ← Move (1, 4) from positions [0:2] to position 1
# Step 3: 4321
#        ← Move (2, 1) from positions [0:2] to position 2
#
# PATH 294:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (4,) from positions [3:4] to position 1
# Step 2: 2143
#        ← Move (1, 4) from positions [0:2] to position 1
# Step 3: 4321
#        ← Move (4, 3) from positions [2:4] to position 0
#
# PATH 295:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (4,) from positions [3:4] to position 1
# Step 2: 4213
#        ← Move (4, 2) from positions [1:3] to position 0
# Step 3: 4321
#        ← Move (2, 1) from positions [1:3] to position 2
#
# PATH 296:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (4,) from positions [3:4] to position 1
# Step 2: 4213
#        ← Move (4, 2) from positions [1:3] to position 0
# Step 3: 4321
#        ← Move (3,) from positions [3:4] to position 1
#
# PATH 297:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (4,) from positions [3:4] to position 1
# Step 2: 4231
#        ← Move (4, 2, 3) from positions [1:4] to position 0
# Step 3: 4321
#        ← Move (2,) from positions [1:2] to position 2
#
# PATH 298:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (4,) from positions [3:4] to position 1
# Step 2: 4231
#        ← Move (4, 2, 3) from positions [1:4] to position 0
# Step 3: 4321
#        ← Move (3,) from positions [2:3] to position 1
#
# PATH 299:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (4,) from positions [3:4] to position 1
# Step 2: 2143
#        ← Move (2,) from positions [2:3] to position 0
# Step 3: 4321
#        ← Move (2, 1) from positions [0:2] to position 2
#
# PATH 300:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (4,) from positions [3:4] to position 1
# Step 2: 2143
#        ← Move (2,) from positions [2:3] to position 0
# Step 3: 4321
#        ← Move (4, 3) from positions [2:4] to position 0
#
# PATH 301:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (4,) from positions [3:4] to position 1
# Step 2: 1432
#        ← Move (2,) from positions [2:3] to position 3
# Step 3: 4321
#        ← Move (1,) from positions [0:1] to position 3
#
# PATH 302:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (4,) from positions [3:4] to position 1
# Step 2: 1432
#        ← Move (2,) from positions [2:3] to position 3
# Step 3: 4321
#        ← Move (4, 3, 2) from positions [1:4] to position 0
#
# PATH 303:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (4,) from positions [3:4] to position 1
# Step 2: 1432
#        ← Move (3,) from positions [3:4] to position 2
# Step 3: 4321
#        ← Move (1,) from positions [0:1] to position 3
#
# PATH 304:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1423
#        ← Move (4,) from positions [3:4] to position 1
# Step 2: 1432
#        ← Move (3,) from positions [3:4] to position 2
# Step 3: 4321
#        ← Move (4, 3, 2) from positions [1:4] to position 0
#
# PATH 305:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1243
#        ← Move (4,) from positions [3:4] to position 2
# Step 2: 2143
#        ← Move (1,) from positions [0:1] to position 1
# Step 3: 4321
#        ← Move (2, 1) from positions [0:2] to position 2
#
# PATH 306:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1243
#        ← Move (4,) from positions [3:4] to position 2
# Step 2: 2143
#        ← Move (1,) from positions [0:1] to position 1
# Step 3: 4321
#        ← Move (4, 3) from positions [2:4] to position 0
#
# PATH 307:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1243
#        ← Move (4,) from positions [3:4] to position 2
# Step 2: 2431
#        ← Move (1,) from positions [0:1] to position 3
# Step 3: 4321
#        ← Move (2,) from positions [0:1] to position 2
#
# PATH 308:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1243
#        ← Move (4,) from positions [3:4] to position 2
# Step 2: 2431
#        ← Move (1,) from positions [0:1] to position 3
# Step 3: 4321
#        ← Move (4, 3) from positions [1:3] to position 0
#
# PATH 309:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1243
#        ← Move (4,) from positions [3:4] to position 2
# Step 2: 4312
#        ← Move (1, 2) from positions [0:2] to position 2
# Step 3: 4321
#        ← Move (1,) from positions [2:3] to position 3
#
# PATH 310:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1243
#        ← Move (4,) from positions [3:4] to position 2
# Step 2: 4312
#        ← Move (1, 2) from positions [0:2] to position 2
# Step 3: 4321
#        ← Move (2,) from positions [3:4] to position 2
#
# PATH 311:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1243
#        ← Move (4,) from positions [3:4] to position 2
# Step 2: 2143
#        ← Move (2,) from positions [1:2] to position 0
# Step 3: 4321
#        ← Move (2, 1) from positions [0:2] to position 2
#
# PATH 312:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1243
#        ← Move (4,) from positions [3:4] to position 2
# Step 2: 2143
#        ← Move (2,) from positions [1:2] to position 0
# Step 3: 4321
#        ← Move (4, 3) from positions [2:4] to position 0
#
# PATH 313:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1243
#        ← Move (4,) from positions [3:4] to position 2
# Step 2: 1432
#        ← Move (2,) from positions [1:2] to position 3
# Step 3: 4321
#        ← Move (1,) from positions [0:1] to position 3
#
# PATH 314:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1243
#        ← Move (4,) from positions [3:4] to position 2
# Step 2: 1432
#        ← Move (2,) from positions [1:2] to position 3
# Step 3: 4321
#        ← Move (4, 3, 2) from positions [1:4] to position 0
#
# PATH 315:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1243
#        ← Move (4,) from positions [3:4] to position 2
# Step 2: 2431
#        ← Move (2, 4, 3) from positions [1:4] to position 0
# Step 3: 4321
#        ← Move (2,) from positions [0:1] to position 2
#
# PATH 316:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1243
#        ← Move (4,) from positions [3:4] to position 2
# Step 2: 2431
#        ← Move (2, 4, 3) from positions [1:4] to position 0
# Step 3: 4321
#        ← Move (4, 3) from positions [1:3] to position 0
#
# PATH 317:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1243
#        ← Move (4,) from positions [3:4] to position 2
# Step 2: 4312
#        ← Move (4, 3) from positions [2:4] to position 0
# Step 3: 4321
#        ← Move (1,) from positions [2:3] to position 3
#
# PATH 318:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1243
#        ← Move (4,) from positions [3:4] to position 2
# Step 2: 4312
#        ← Move (4, 3) from positions [2:4] to position 0
# Step 3: 4321
#        ← Move (2,) from positions [3:4] to position 2
#
# PATH 319:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1243
#        ← Move (4,) from positions [3:4] to position 2
# Step 2: 1432
#        ← Move (4, 3) from positions [2:4] to position 1
# Step 3: 4321
#        ← Move (1,) from positions [0:1] to position 3
#
# PATH 320:
# ----------------------------------------
# Step 0: 1234 (start)
# Step 1: 1243
#        ← Move (4,) from positions [3:4] to position 2
# Step 2: 1432
#        ← Move (4, 3) from positions [2:4] to position 1
# Step 3: 4321
#        ← Move (4, 3, 2) from positions [1:4] to position 0
#
#
# SUMMARY:
# Total number of different 3-step paths: 320
#
# ================================================================================
# VERIFICATION: What is the actual shortest path length?
# Shortest path length: 3

# %%
from itertools import permutations
from collections import deque
import heapq

def generate_single_translocation(perm, start_idx, end_idx, insert_pos):
    """
    Generate a single translocation: move interval [start_idx:end_idx] to insert_pos.
    Returns the resulting permutation.
    """
    # Extract the interval (keeping its internal order)
    interval = perm[start_idx:end_idx]
    # Get the remaining elements
    remaining = perm[:start_idx] + perm[end_idx:]
    # Insert interval at the specified position
    result = remaining[:insert_pos] + interval + remaining[insert_pos:]
    return result

def get_all_possible_translocations(perm):
    """
    Get all possible single translocations from a given permutation.
    Returns list of (result_permutation, move_info) tuples.
    """
    translocations = []
    n = len(perm)
    
    # Try all possible intervals
    for start_idx in range(n):
        for end_idx in range(start_idx + 1, n + 1):
            interval = perm[start_idx:end_idx]
            remaining = perm[:start_idx] + perm[end_idx:]
            
            # Try all possible insertion positions
            for insert_pos in range(len(remaining) + 1):
                result = remaining[:insert_pos] + interval + remaining[insert_pos:]
                
                # Only include if different from original
                if result != perm:
                    move_info = {
                        'interval': interval,
                        'from_pos': (start_idx, end_idx),
                        'to_pos': insert_pos,
                        'description': f"Move {interval} from positions [{start_idx}:{end_idx}] to position {insert_pos}"
                    }
                    translocations.append((result, move_info))
    
    return translocations

def find_all_paths_exact_length(start_perm, target_perm, exact_length):
    """
    Find ALL possible paths of exactly the specified length.
    Returns list of (path, moves) tuples.
    """
    all_paths = []
    
    # Use DFS to explore all paths
    def dfs(current_perm, current_path, current_moves, remaining_steps):
        if remaining_steps == 0:
            if current_perm == target_perm:
                all_paths.append((current_path.copy(), current_moves.copy()))
            return
        
        # Generate all possible moves from current position
        possible_moves = get_all_possible_translocations(current_perm)
        
        for next_perm, move_info in possible_moves:
            # Avoid revisiting the same permutation in the current path (cycle detection)
            if next_perm not in current_path:
                current_path.append(next_perm)
                current_moves.append(move_info)
                
                dfs(next_perm, current_path, current_moves, remaining_steps - 1)
                
                # Backtrack
                current_path.pop()
                current_moves.pop()
    
    # Start DFS
    dfs(start_perm, [start_perm], [], exact_length)
    
    return all_paths

def analyze_all_paths(start_perm, target_perm, exact_length):
    """
    Find and display all possible paths of exact length.
    """
    start_str = ''.join(map(str, start_perm))
    target_str = ''.join(map(str, target_perm))
    
    print(f"FINDING ALL PATHS: {start_str} → {target_str} in exactly {exact_length} steps")
    print("=" * 80)
    
    all_paths = find_all_paths_exact_length(start_perm, target_perm, exact_length)
    
    if not all_paths:
        print(f"No paths found of exactly {exact_length} steps!")
        return
    
    print(f"Found {len(all_paths)} different paths of exactly {exact_length} steps:")
    print()
    
    for path_num, (path, moves) in enumerate(all_paths, 1):
        print(f"PATH {path_num}:")
        print("-" * 40)
        
        for i, perm in enumerate(path):
            perm_str = ''.join(map(str, perm))
            if i == 0:
                print(f"Step {i}: {perm_str} (start)")
            else:
                print(f"Step {i}: {perm_str}")
                print(f"       ← {moves[i-1]['description']}")
        
        print()
    
    return all_paths

def find_shortest_path_length(start_perm, target_perm, max_depth=10):
    """
    Find the shortest path length using BFS.
    """
    if start_perm == target_perm:
        return 0
    
    queue = deque([(start_perm, 0)])
    visited = {start_perm}
    
    while queue:
        current_perm, depth = queue.popleft()
        
        if depth >= max_depth:
            continue
            
        moves = get_all_possible_translocations(current_perm)
        for next_perm, _ in moves:
            if next_perm == target_perm:
                return depth + 1
            
            if next_perm not in visited:
                visited.add(next_perm)
                queue.append((next_perm, depth + 1))
    
    return float('inf')

def comprehensive_analysis(start_perm, target_perm):
    """
    Comprehensive analysis: find shortest path, then show all paths of that length.
    """
    start_str = ''.join(map(str, start_perm))
    target_str = ''.join(map(str, target_perm))
    
    print(f"COMPREHENSIVE ANALYSIS: {start_str} → {target_str}")
    print("=" * 80)
    
    # First, find the shortest path length
    shortest_length = find_shortest_path_length(start_perm, target_perm)
    
    if shortest_length == float('inf'):
        print("No path found!")
        return
    
    print(f"Shortest path length: {shortest_length} steps")
    print()
    
    # Now find all paths of that length
    analyze_all_paths(start_perm, target_perm, shortest_length)
    
    # Also show paths of length shortest_length + 1 if requested
    if shortest_length < 5:  # Don't go too deep
        print(f"\nPaths of length {shortest_length + 1}:")
        print("=" * 80)
        longer_paths = find_all_paths_exact_length(start_perm, target_perm, shortest_length + 1)
        print(f"Found {len(longer_paths)} paths of length {shortest_length + 1}")

def analyze_step_by_step_translocations(start_perm, target_perm):
    """
    Analyze all possible first and second translocations systematically.
    """
    start_str = ''.join(map(str, start_perm))
    target_str = ''.join(map(str, target_perm))
    
    print(f"STEP-BY-STEP ANALYSIS: {start_str} → {target_str}")
    print("=" * 80)
    
    # Get all possible first translocations
    first_moves = get_all_possible_translocations(start_perm)
    
    print(f"ALL POSSIBLE FIRST TRANSLOCATIONS from {start_str}:")
    print("-" * 60)
    
    first_results = {}  # Store results for second step analysis
    
    for i, (result_perm, move_info) in enumerate(first_moves, 1):
        result_str = ''.join(map(str, result_perm))
        print(f"{i:2d}. {start_str} → {result_str}")
        print(f"    Operation: {move_info['description']}")
        
        # Group by result for second step analysis
        if result_perm not in first_results:
            first_results[result_perm] = []
        first_results[result_perm].append((i, move_info))
        print()
    
    print(f"Total: {len(first_moves)} possible first translocations")
    print(f"Leading to {len(first_results)} unique intermediate permutations")
    
    print("\n" + "=" * 80)
    print("ALL POSSIBLE SECOND TRANSLOCATIONS:")
    print("-" * 60)
    
    second_step_count = 0
    paths_to_target = []
    
    for intermediate_perm, first_move_list in first_results.items():
        intermediate_str = ''.join(map(str, intermediate_perm))
        
        # Get all possible second moves from this intermediate state
        second_moves = get_all_possible_translocations(intermediate_perm)
        
        print(f"\nFrom intermediate state {intermediate_str}:")
        print(f"(Reachable via {len(first_move_list)} different first moves)")
        
        for j, (second_result, second_move_info) in enumerate(second_moves, 1):
            second_result_str = ''.join(map(str, second_result))
            second_step_count += len(first_move_list)  # Count all combinations
            
            print(f"  {j:2d}. {intermediate_str} → {second_result_str}")
            print(f"      Operation: {second_move_info['description']}")
            
            # Check if this reaches the target
            if second_result == target_perm:
                print(f"      *** REACHES TARGET! ***")
                for first_move_num, first_move_info in first_move_list:
                    paths_to_target.append({
                        'first_move': (first_move_num, first_move_info),
                        'intermediate': intermediate_perm,
                        'second_move': (j, second_move_info),
                        'path': [start_perm, intermediate_perm, second_result]
                    })
    
    print(f"\nTotal possible second translocations: {second_step_count}")
    print(f"2-step paths that reach target: {len(paths_to_target)}")
    
    if paths_to_target:
        print("\n" + "=" * 80)
        print("ALL 2-STEP SOLUTIONS:")
        print("-" * 60)
        
        for i, path_info in enumerate(paths_to_target, 1):
            print(f"\nSOLUTION {i}:")
            path = path_info['path']
            
            print(f"Step 0: {''.join(map(str, path[0]))} (start)")
            print(f"Step 1: {''.join(map(str, path[1]))}")
            print(f"        ← {path_info['first_move'][1]['description']}")
            print(f"Step 2: {''.join(map(str, path[2]))} (target reached!)")
            print(f"        ← {path_info['second_move'][1]['description']}")
    
    return first_results, paths_to_target

def analyze_third_step_from_2step_failures(start_perm, target_perm):
    """
    For states that don't reach target in 2 steps, show what third step options exist.
    """
    print("\n" + "=" * 80)
    print("THIRD STEP ANALYSIS (for 3-step solutions):")
    print("-" * 60)
    
    # Get all possible 2-step states
    first_moves = get_all_possible_translocations(start_perm)
    two_step_states = set()
    two_step_paths = {}  # state -> list of ways to reach it
    
    for result1, move1 in first_moves:
        second_moves = get_all_possible_translocations(result1)
        for result2, move2 in second_moves:
            if result2 != target_perm:  # Only non-target states
                two_step_states.add(result2)
                if result2 not in two_step_paths:
                    two_step_paths[result2] = []
                two_step_paths[result2].append((move1, result1, move2))
    
    print(f"Found {len(two_step_states)} unique states reachable in 2 steps (excluding target)")
    
    three_step_solutions = []
    
    for state in two_step_states:
        state_str = ''.join(map(str, state))
        third_moves = get_all_possible_translocations(state)
        
        # Check which third moves reach the target
        target_reaching_moves = [(move, result) for result, move in third_moves if result == target_perm]
        
        if target_reaching_moves:
            print(f"\nFrom 2-step state {state_str}:")
            print(f"  Can reach target in {len(target_reaching_moves)} ways:")
            
            for move, result in target_reaching_moves:
                print(f"    • {move['description']}")
                
                # Add all complete 3-step paths
                for path_info in two_step_paths[state]:
                    three_step_solutions.append({
                        'step1': path_info[0],
                        'intermediate1': path_info[1], 
                        'step2': path_info[2],
                        'intermediate2': state,
                        'step3': move,
                        'final': result
                    })
    
    print(f"\nTotal 3-step solutions found: {len(three_step_solutions)}")
    
    if three_step_solutions and len(three_step_solutions) <= 20:  # Don't print too many
        print("\nAll 3-step solutions:")
        for i, sol in enumerate(three_step_solutions, 1):
            print(f"\nSOLUTION {i}:")
            print(f"  {start_str} → {''.join(map(str, sol['intermediate1']))} → {''.join(map(str, sol['intermediate2']))} → {target_str}")
            print(f"    Step 1: {sol['step1']['description']}")
            print(f"    Step 2: {sol['step2']['description']}")  
            print(f"    Step 3: {sol['step3']['description']}")
    
    return three_step_solutions

if __name__ == "__main__":
    # Main test case: 1234 → 4321
    start = (4, 3, 2, 1)
    target = (1, 2, 3, 4)
    start_str = ''.join(map(str, start))
    target_str = ''.join(map(str, target))
    
    # Analyze step by step
    first_results, two_step_solutions = analyze_step_by_step_translocations(start, target)
    
    # If no 2-step solutions, analyze 3-step
    if not two_step_solutions:
        three_step_solutions = analyze_third_step_from_2step_failures(start, target)
    
    print("\n" + "=" * 80)
    print("SUMMARY:")
    print(f"• Total possible first translocations: {len(get_all_possible_translocations(start))}")
    print(f"• 2-step solutions: {len(two_step_solutions)}")
    if not two_step_solutions:
        print(f"• 3-step solutions: {len(three_step_solutions) if 'three_step_solutions' in locals() else 'Not calculated'}")
    
    # Also verify with our original comprehensive analysis
    print(f"\nVerification - finding shortest path length:")
    shortest = find_shortest_path_length(start, target)
    print(f"Minimum steps required: {shortest}")
# Out:
# STEP-BY-STEP ANALYSIS: 4321 → 1234
# ================================================================================
# ALL POSSIBLE FIRST TRANSLOCATIONS from 4321:
# ------------------------------------------------------------
#  1. 4321 → 3421
#     Operation: Move (4,) from positions [0:1] to position 1
#
#  2. 4321 → 3241
#     Operation: Move (4,) from positions [0:1] to position 2
#
#  3. 4321 → 3214
#     Operation: Move (4,) from positions [0:1] to position 3
#
#  4. 4321 → 2431
#     Operation: Move (4, 3) from positions [0:2] to position 1
#
#  5. 4321 → 2143
#     Operation: Move (4, 3) from positions [0:2] to position 2
#
#  6. 4321 → 1432
#     Operation: Move (4, 3, 2) from positions [0:3] to position 1
#
#  7. 4321 → 3421
#     Operation: Move (3,) from positions [1:2] to position 0
#
#  8. 4321 → 4231
#     Operation: Move (3,) from positions [1:2] to position 2
#
#  9. 4321 → 4213
#     Operation: Move (3,) from positions [1:2] to position 3
#
# 10. 4321 → 3241
#     Operation: Move (3, 2) from positions [1:3] to position 0
#
# 11. 4321 → 4132
#     Operation: Move (3, 2) from positions [1:3] to position 2
#
# 12. 4321 → 3214
#     Operation: Move (3, 2, 1) from positions [1:4] to position 0
#
# 13. 4321 → 2431
#     Operation: Move (2,) from positions [2:3] to position 0
#
# 14. 4321 → 4231
#     Operation: Move (2,) from positions [2:3] to position 1
#
# 15. 4321 → 4312
#     Operation: Move (2,) from positions [2:3] to position 3
#
# 16. 4321 → 2143
#     Operation: Move (2, 1) from positions [2:4] to position 0
#
# 17. 4321 → 4213
#     Operation: Move (2, 1) from positions [2:4] to position 1
#
# 18. 4321 → 1432
#     Operation: Move (1,) from positions [3:4] to position 0
#
# 19. 4321 → 4132
#     Operation: Move (1,) from positions [3:4] to position 1
#
# 20. 4321 → 4312
#     Operation: Move (1,) from positions [3:4] to position 2
#
# Total: 20 possible first translocations
# Leading to 10 unique intermediate permutations
#
# ================================================================================
# ALL POSSIBLE SECOND TRANSLOCATIONS:
# ------------------------------------------------------------
#
# From intermediate state 3421:
# (Reachable via 2 different first moves)
#    1. 3421 → 4321
#       Operation: Move (3,) from positions [0:1] to position 1
#    2. 3421 → 4231
#       Operation: Move (3,) from positions [0:1] to position 2
#    3. 3421 → 4213
#       Operation: Move (3,) from positions [0:1] to position 3
#    4. 3421 → 2341
#       Operation: Move (3, 4) from positions [0:2] to position 1
#    5. 3421 → 2134
#       Operation: Move (3, 4) from positions [0:2] to position 2
#    6. 3421 → 1342
#       Operation: Move (3, 4, 2) from positions [0:3] to position 1
#    7. 3421 → 4321
#       Operation: Move (4,) from positions [1:2] to position 0
#    8. 3421 → 3241
#       Operation: Move (4,) from positions [1:2] to position 2
#    9. 3421 → 3214
#       Operation: Move (4,) from positions [1:2] to position 3
#   10. 3421 → 4231
#       Operation: Move (4, 2) from positions [1:3] to position 0
#   11. 3421 → 3142
#       Operation: Move (4, 2) from positions [1:3] to position 2
#   12. 3421 → 4213
#       Operation: Move (4, 2, 1) from positions [1:4] to position 0
#   13. 3421 → 2341
#       Operation: Move (2,) from positions [2:3] to position 0
#   14. 3421 → 3241
#       Operation: Move (2,) from positions [2:3] to position 1
#   15. 3421 → 3412
#       Operation: Move (2,) from positions [2:3] to position 3
#   16. 3421 → 2134
#       Operation: Move (2, 1) from positions [2:4] to position 0
#   17. 3421 → 3214
#       Operation: Move (2, 1) from positions [2:4] to position 1
#   18. 3421 → 1342
#       Operation: Move (1,) from positions [3:4] to position 0
#   19. 3421 → 3142
#       Operation: Move (1,) from positions [3:4] to position 1
#   20. 3421 → 3412
#       Operation: Move (1,) from positions [3:4] to position 2
#
# From intermediate state 3241:
# (Reachable via 2 different first moves)
#    1. 3241 → 2341
#       Operation: Move (3,) from positions [0:1] to position 1
#    2. 3241 → 2431
#       Operation: Move (3,) from positions [0:1] to position 2
#    3. 3241 → 2413
#       Operation: Move (3,) from positions [0:1] to position 3
#    4. 3241 → 4321
#       Operation: Move (3, 2) from positions [0:2] to position 1
#    5. 3241 → 4132
#       Operation: Move (3, 2) from positions [0:2] to position 2
#    6. 3241 → 1324
#       Operation: Move (3, 2, 4) from positions [0:3] to position 1
#    7. 3241 → 2341
#       Operation: Move (2,) from positions [1:2] to position 0
#    8. 3241 → 3421
#       Operation: Move (2,) from positions [1:2] to position 2
#    9. 3241 → 3412
#       Operation: Move (2,) from positions [1:2] to position 3
#   10. 3241 → 2431
#       Operation: Move (2, 4) from positions [1:3] to position 0
#   11. 3241 → 3124
#       Operation: Move (2, 4) from positions [1:3] to position 2
#   12. 3241 → 2413
#       Operation: Move (2, 4, 1) from positions [1:4] to position 0
#   13. 3241 → 4321
#       Operation: Move (4,) from positions [2:3] to position 0
#   14. 3241 → 3421
#       Operation: Move (4,) from positions [2:3] to position 1
#   15. 3241 → 3214
#       Operation: Move (4,) from positions [2:3] to position 3
#   16. 3241 → 4132
#       Operation: Move (4, 1) from positions [2:4] to position 0
#   17. 3241 → 3412
#       Operation: Move (4, 1) from positions [2:4] to position 1
#   18. 3241 → 1324
#       Operation: Move (1,) from positions [3:4] to position 0
#   19. 3241 → 3124
#       Operation: Move (1,) from positions [3:4] to position 1
#   20. 3241 → 3214
#       Operation: Move (1,) from positions [3:4] to position 2
#
# From intermediate state 3214:
# (Reachable via 2 different first moves)
#    1. 3214 → 2314
#       Operation: Move (3,) from positions [0:1] to position 1
#    2. 3214 → 2134
#       Operation: Move (3,) from positions [0:1] to position 2
#    3. 3214 → 2143
#       Operation: Move (3,) from positions [0:1] to position 3
#    4. 3214 → 1324
#       Operation: Move (3, 2) from positions [0:2] to position 1
#    5. 3214 → 1432
#       Operation: Move (3, 2) from positions [0:2] to position 2
#    6. 3214 → 4321
#       Operation: Move (3, 2, 1) from positions [0:3] to position 1
#    7. 3214 → 2314
#       Operation: Move (2,) from positions [1:2] to position 0
#    8. 3214 → 3124
#       Operation: Move (2,) from positions [1:2] to position 2
#    9. 3214 → 3142
#       Operation: Move (2,) from positions [1:2] to position 3
#   10. 3214 → 2134
#       Operation: Move (2, 1) from positions [1:3] to position 0
#   11. 3214 → 3421
#       Operation: Move (2, 1) from positions [1:3] to position 2
#   12. 3214 → 2143
#       Operation: Move (2, 1, 4) from positions [1:4] to position 0
#   13. 3214 → 1324
#       Operation: Move (1,) from positions [2:3] to position 0
#   14. 3214 → 3124
#       Operation: Move (1,) from positions [2:3] to position 1
#   15. 3214 → 3241
#       Operation: Move (1,) from positions [2:3] to position 3
#   16. 3214 → 1432
#       Operation: Move (1, 4) from positions [2:4] to position 0
#   17. 3214 → 3142
#       Operation: Move (1, 4) from positions [2:4] to position 1
#   18. 3214 → 4321
#       Operation: Move (4,) from positions [3:4] to position 0
#   19. 3214 → 3421
#       Operation: Move (4,) from positions [3:4] to position 1
#   20. 3214 → 3241
#       Operation: Move (4,) from positions [3:4] to position 2
#
# From intermediate state 2431:
# (Reachable via 2 different first moves)
#    1. 2431 → 4231
#       Operation: Move (2,) from positions [0:1] to position 1
#    2. 2431 → 4321
#       Operation: Move (2,) from positions [0:1] to position 2
#    3. 2431 → 4312
#       Operation: Move (2,) from positions [0:1] to position 3
#    4. 2431 → 3241
#       Operation: Move (2, 4) from positions [0:2] to position 1
#    5. 2431 → 3124
#       Operation: Move (2, 4) from positions [0:2] to position 2
#    6. 2431 → 1243
#       Operation: Move (2, 4, 3) from positions [0:3] to position 1
#    7. 2431 → 4231
#       Operation: Move (4,) from positions [1:2] to position 0
#    8. 2431 → 2341
#       Operation: Move (4,) from positions [1:2] to position 2
#    9. 2431 → 2314
#       Operation: Move (4,) from positions [1:2] to position 3
#   10. 2431 → 4321
#       Operation: Move (4, 3) from positions [1:3] to position 0
#   11. 2431 → 2143
#       Operation: Move (4, 3) from positions [1:3] to position 2
#   12. 2431 → 4312
#       Operation: Move (4, 3, 1) from positions [1:4] to position 0
#   13. 2431 → 3241
#       Operation: Move (3,) from positions [2:3] to position 0
#   14. 2431 → 2341
#       Operation: Move (3,) from positions [2:3] to position 1
#   15. 2431 → 2413
#       Operation: Move (3,) from positions [2:3] to position 3
#   16. 2431 → 3124
#       Operation: Move (3, 1) from positions [2:4] to position 0
#   17. 2431 → 2314
#       Operation: Move (3, 1) from positions [2:4] to position 1
#   18. 2431 → 1243
#       Operation: Move (1,) from positions [3:4] to position 0
#   19. 2431 → 2143
#       Operation: Move (1,) from positions [3:4] to position 1
#   20. 2431 → 2413
#       Operation: Move (1,) from positions [3:4] to position 2
#
# From intermediate state 2143:
# (Reachable via 2 different first moves)
#    1. 2143 → 1243
#       Operation: Move (2,) from positions [0:1] to position 1
#    2. 2143 → 1423
#       Operation: Move (2,) from positions [0:1] to position 2
#    3. 2143 → 1432
#       Operation: Move (2,) from positions [0:1] to position 3
#    4. 2143 → 4213
#       Operation: Move (2, 1) from positions [0:2] to position 1
#    5. 2143 → 4321
#       Operation: Move (2, 1) from positions [0:2] to position 2
#    6. 2143 → 3214
#       Operation: Move (2, 1, 4) from positions [0:3] to position 1
#    7. 2143 → 1243
#       Operation: Move (1,) from positions [1:2] to position 0
#    8. 2143 → 2413
#       Operation: Move (1,) from positions [1:2] to position 2
#    9. 2143 → 2431
#       Operation: Move (1,) from positions [1:2] to position 3
#   10. 2143 → 1423
#       Operation: Move (1, 4) from positions [1:3] to position 0
#   11. 2143 → 2314
#       Operation: Move (1, 4) from positions [1:3] to position 2
#   12. 2143 → 1432
#       Operation: Move (1, 4, 3) from positions [1:4] to position 0
#   13. 2143 → 4213
#       Operation: Move (4,) from positions [2:3] to position 0
#   14. 2143 → 2413
#       Operation: Move (4,) from positions [2:3] to position 1
#   15. 2143 → 2134
#       Operation: Move (4,) from positions [2:3] to position 3
#   16. 2143 → 4321
#       Operation: Move (4, 3) from positions [2:4] to position 0
#   17. 2143 → 2431
#       Operation: Move (4, 3) from positions [2:4] to position 1
#   18. 2143 → 3214
#       Operation: Move (3,) from positions [3:4] to position 0
#   19. 2143 → 2314
#       Operation: Move (3,) from positions [3:4] to position 1
#   20. 2143 → 2134
#       Operation: Move (3,) from positions [3:4] to position 2
#
# From intermediate state 1432:
# (Reachable via 2 different first moves)
#    1. 1432 → 4132
#       Operation: Move (1,) from positions [0:1] to position 1
#    2. 1432 → 4312
#       Operation: Move (1,) from positions [0:1] to position 2
#    3. 1432 → 4321
#       Operation: Move (1,) from positions [0:1] to position 3
#    4. 1432 → 3142
#       Operation: Move (1, 4) from positions [0:2] to position 1
#    5. 1432 → 3214
#       Operation: Move (1, 4) from positions [0:2] to position 2
#    6. 1432 → 2143
#       Operation: Move (1, 4, 3) from positions [0:3] to position 1
#    7. 1432 → 4132
#       Operation: Move (4,) from positions [1:2] to position 0
#    8. 1432 → 1342
#       Operation: Move (4,) from positions [1:2] to position 2
#    9. 1432 → 1324
#       Operation: Move (4,) from positions [1:2] to position 3
#   10. 1432 → 4312
#       Operation: Move (4, 3) from positions [1:3] to position 0
#   11. 1432 → 1243
#       Operation: Move (4, 3) from positions [1:3] to position 2
#   12. 1432 → 4321
#       Operation: Move (4, 3, 2) from positions [1:4] to position 0
#   13. 1432 → 3142
#       Operation: Move (3,) from positions [2:3] to position 0
#   14. 1432 → 1342
#       Operation: Move (3,) from positions [2:3] to position 1
#   15. 1432 → 1423
#       Operation: Move (3,) from positions [2:3] to position 3
#   16. 1432 → 3214
#       Operation: Move (3, 2) from positions [2:4] to position 0
#   17. 1432 → 1324
#       Operation: Move (3, 2) from positions [2:4] to position 1
#   18. 1432 → 2143
#       Operation: Move (2,) from positions [3:4] to position 0
#   19. 1432 → 1243
#       Operation: Move (2,) from positions [3:4] to position 1
#   20. 1432 → 1423
#       Operation: Move (2,) from positions [3:4] to position 2
#
# From intermediate state 4231:
# (Reachable via 2 different first moves)
#    1. 4231 → 2431
#       Operation: Move (4,) from positions [0:1] to position 1
#    2. 4231 → 2341
#       Operation: Move (4,) from positions [0:1] to position 2
#    3. 4231 → 2314
#       Operation: Move (4,) from positions [0:1] to position 3
#    4. 4231 → 3421
#       Operation: Move (4, 2) from positions [0:2] to position 1
#    5. 4231 → 3142
#       Operation: Move (4, 2) from positions [0:2] to position 2
#    6. 4231 → 1423
#       Operation: Move (4, 2, 3) from positions [0:3] to position 1
#    7. 4231 → 2431
#       Operation: Move (2,) from positions [1:2] to position 0
#    8. 4231 → 4321
#       Operation: Move (2,) from positions [1:2] to position 2
#    9. 4231 → 4312
#       Operation: Move (2,) from positions [1:2] to position 3
#   10. 4231 → 2341
#       Operation: Move (2, 3) from positions [1:3] to position 0
#   11. 4231 → 4123
#       Operation: Move (2, 3) from positions [1:3] to position 2
#   12. 4231 → 2314
#       Operation: Move (2, 3, 1) from positions [1:4] to position 0
#   13. 4231 → 3421
#       Operation: Move (3,) from positions [2:3] to position 0
#   14. 4231 → 4321
#       Operation: Move (3,) from positions [2:3] to position 1
#   15. 4231 → 4213
#       Operation: Move (3,) from positions [2:3] to position 3
#   16. 4231 → 3142
#       Operation: Move (3, 1) from positions [2:4] to position 0
#   17. 4231 → 4312
#       Operation: Move (3, 1) from positions [2:4] to position 1
#   18. 4231 → 1423
#       Operation: Move (1,) from positions [3:4] to position 0
#   19. 4231 → 4123
#       Operation: Move (1,) from positions [3:4] to position 1
#   20. 4231 → 4213
#       Operation: Move (1,) from positions [3:4] to position 2
#
# From intermediate state 4213:
# (Reachable via 2 different first moves)
#    1. 4213 → 2413
#       Operation: Move (4,) from positions [0:1] to position 1
#    2. 4213 → 2143
#       Operation: Move (4,) from positions [0:1] to position 2
#    3. 4213 → 2134
#       Operation: Move (4,) from positions [0:1] to position 3
#    4. 4213 → 1423
#       Operation: Move (4, 2) from positions [0:2] to position 1
#    5. 4213 → 1342
#       Operation: Move (4, 2) from positions [0:2] to position 2
#    6. 4213 → 3421
#       Operation: Move (4, 2, 1) from positions [0:3] to position 1
#    7. 4213 → 2413
#       Operation: Move (2,) from positions [1:2] to position 0
#    8. 4213 → 4123
#       Operation: Move (2,) from positions [1:2] to position 2
#    9. 4213 → 4132
#       Operation: Move (2,) from positions [1:2] to position 3
#   10. 4213 → 2143
#       Operation: Move (2, 1) from positions [1:3] to position 0
#   11. 4213 → 4321
#       Operation: Move (2, 1) from positions [1:3] to position 2
#   12. 4213 → 2134
#       Operation: Move (2, 1, 3) from positions [1:4] to position 0
#   13. 4213 → 1423
#       Operation: Move (1,) from positions [2:3] to position 0
#   14. 4213 → 4123
#       Operation: Move (1,) from positions [2:3] to position 1
#   15. 4213 → 4231
#       Operation: Move (1,) from positions [2:3] to position 3
#   16. 4213 → 1342
#       Operation: Move (1, 3) from positions [2:4] to position 0
#   17. 4213 → 4132
#       Operation: Move (1, 3) from positions [2:4] to position 1
#   18. 4213 → 3421
#       Operation: Move (3,) from positions [3:4] to position 0
#   19. 4213 → 4321
#       Operation: Move (3,) from positions [3:4] to position 1
#   20. 4213 → 4231
#       Operation: Move (3,) from positions [3:4] to position 2
#
# From intermediate state 4132:
# (Reachable via 2 different first moves)
#    1. 4132 → 1432
#       Operation: Move (4,) from positions [0:1] to position 1
#    2. 4132 → 1342
#       Operation: Move (4,) from positions [0:1] to position 2
#    3. 4132 → 1324
#       Operation: Move (4,) from positions [0:1] to position 3
#    4. 4132 → 3412
#       Operation: Move (4, 1) from positions [0:2] to position 1
#    5. 4132 → 3241
#       Operation: Move (4, 1) from positions [0:2] to position 2
#    6. 4132 → 2413
#       Operation: Move (4, 1, 3) from positions [0:3] to position 1
#    7. 4132 → 1432
#       Operation: Move (1,) from positions [1:2] to position 0
#    8. 4132 → 4312
#       Operation: Move (1,) from positions [1:2] to position 2
#    9. 4132 → 4321
#       Operation: Move (1,) from positions [1:2] to position 3
#   10. 4132 → 1342
#       Operation: Move (1, 3) from positions [1:3] to position 0
#   11. 4132 → 4213
#       Operation: Move (1, 3) from positions [1:3] to position 2
#   12. 4132 → 1324
#       Operation: Move (1, 3, 2) from positions [1:4] to position 0
#   13. 4132 → 3412
#       Operation: Move (3,) from positions [2:3] to position 0
#   14. 4132 → 4312
#       Operation: Move (3,) from positions [2:3] to position 1
#   15. 4132 → 4123
#       Operation: Move (3,) from positions [2:3] to position 3
#   16. 4132 → 3241
#       Operation: Move (3, 2) from positions [2:4] to position 0
#   17. 4132 → 4321
#       Operation: Move (3, 2) from positions [2:4] to position 1
#   18. 4132 → 2413
#       Operation: Move (2,) from positions [3:4] to position 0
#   19. 4132 → 4213
#       Operation: Move (2,) from positions [3:4] to position 1
#   20. 4132 → 4123
#       Operation: Move (2,) from positions [3:4] to position 2
#
# From intermediate state 4312:
# (Reachable via 2 different first moves)
#    1. 4312 → 3412
#       Operation: Move (4,) from positions [0:1] to position 1
#    2. 4312 → 3142
#       Operation: Move (4,) from positions [0:1] to position 2
#    3. 4312 → 3124
#       Operation: Move (4,) from positions [0:1] to position 3
#    4. 4312 → 1432
#       Operation: Move (4, 3) from positions [0:2] to position 1
#    5. 4312 → 1243
#       Operation: Move (4, 3) from positions [0:2] to position 2
#    6. 4312 → 2431
#       Operation: Move (4, 3, 1) from positions [0:3] to position 1
#    7. 4312 → 3412
#       Operation: Move (3,) from positions [1:2] to position 0
#    8. 4312 → 4132
#       Operation: Move (3,) from positions [1:2] to position 2
#    9. 4312 → 4123
#       Operation: Move (3,) from positions [1:2] to position 3
#   10. 4312 → 3142
#       Operation: Move (3, 1) from positions [1:3] to position 0
#   11. 4312 → 4231
#       Operation: Move (3, 1) from positions [1:3] to position 2
#   12. 4312 → 3124
#       Operation: Move (3, 1, 2) from positions [1:4] to position 0
#   13. 4312 → 1432
#       Operation: Move (1,) from positions [2:3] to position 0
#   14. 4312 → 4132
#       Operation: Move (1,) from positions [2:3] to position 1
#   15. 4312 → 4321
#       Operation: Move (1,) from positions [2:3] to position 3
#   16. 4312 → 1243
#       Operation: Move (1, 2) from positions [2:4] to position 0
#   17. 4312 → 4123
#       Operation: Move (1, 2) from positions [2:4] to position 1
#   18. 4312 → 2431
#       Operation: Move (2,) from positions [3:4] to position 0
#   19. 4312 → 4231
#       Operation: Move (2,) from positions [3:4] to position 1
#   20. 4312 → 4321
#       Operation: Move (2,) from positions [3:4] to position 2
#
# Total possible second translocations: 400
# 2-step paths that reach target: 0
#
# ================================================================================
# THIRD STEP ANALYSIS (for 3-step solutions):
# ------------------------------------------------------------
# Found 23 unique states reachable in 2 steps (excluding target)
#
# From 2-step state 2314:
#   Can reach target in 2 ways:
#     • Move (2, 3) from positions [0:2] to position 1
#     • Move (1,) from positions [2:3] to position 0
#
# From 2-step state 3124:
#   Can reach target in 2 ways:
#     • Move (3,) from positions [0:1] to position 2
#     • Move (1, 2) from positions [1:3] to position 0
#
# From 2-step state 1243:
#   Can reach target in 2 ways:
#     • Move (4,) from positions [2:3] to position 3
#     • Move (3,) from positions [3:4] to position 2
#
# From 2-step state 1423:
#   Can reach target in 2 ways:
#     • Move (4,) from positions [1:2] to position 3
#     • Move (2, 3) from positions [2:4] to position 1
#
# From 2-step state 4123:
#   Can reach target in 2 ways:
#     • Move (4,) from positions [0:1] to position 3
#     • Move (1, 2, 3) from positions [1:4] to position 0
#
# From 2-step state 2134:
#   Can reach target in 2 ways:
#     • Move (2,) from positions [0:1] to position 1
#     • Move (1,) from positions [1:2] to position 0
#
# From 2-step state 3412:
#   Can reach target in 2 ways:
#     • Move (3, 4) from positions [0:2] to position 2
#     • Move (1, 2) from positions [2:4] to position 0
#
# From 2-step state 1342:
#   Can reach target in 2 ways:
#     • Move (3, 4) from positions [1:3] to position 2
#     • Move (2,) from positions [3:4] to position 1
#
# From 2-step state 2341:
#   Can reach target in 2 ways:
#     • Move (2, 3, 4) from positions [0:3] to position 1
#     • Move (1,) from positions [3:4] to position 0
#
# From 2-step state 1324:
#   Can reach target in 2 ways:
#     • Move (3,) from positions [1:2] to position 2
#     • Move (2,) from positions [2:3] to position 1
#
# Total 3-step solutions found: 320
#
# ================================================================================
# SUMMARY:
# • Total possible first translocations: 20
# • 2-step solutions: 0
# • 3-step solutions: 320
#
# Verification - finding shortest path length:
# Minimum steps required: 3
